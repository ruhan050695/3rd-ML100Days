# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#計算 MSE
    y:實際值
    yp:預測值

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y,yp):
    mse = MSE = sum(np.square(y-yp))/len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f"% (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 189.943
# The Mean absolute error is 11.500

# %% [markdown]
# # [作業2]

# %%
Predict Future Sales
1.這組資料之所以重要，是因為
可以提供給店家未來銷量預測，以及不同商店的銷售情況，以利於存貨訂購量。抑或是是廣告投放。
2.資料來源：各分店購物紀錄、進貨紀錄
3.資料型態：結構化的數值、圖表
4.透過回歸分析，來分析各類產品的銷售量、銷售額

# %% [markdown]
# # [作業3]

# %%
1.核心問題為，如何提升服務收入。在尖峰時段時，如何安排載客路線，來減少不必要的時間浪費。
假設，不同時段的服務價格不同，則如何在訂定最適價格，以達到收入最大化。
假設，自由載客車隊會提供異質服務，例如：兒童座椅、廂型車等。甚麼路線或什麼時段需要特別的服務。
例如：校區附近上下課時段，可能備有兒童座椅的需求數可能更高？機場附近路線，比較需要大台廂型車？
2.資料從何而來：乘客的訂車資料以及路線，乘客的需求以及後續回饋。
3.蒐集的資料型態：數值化金額、非數值化的路線圖，以及各特殊需求的需求量。
4.假設如何驗證：透過結合時間和地圖的數值分析，各路線的載客比例，和各項需求的比例。
